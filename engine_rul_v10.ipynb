# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed,SimpleRNN,Dropout,GRU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_excel("D:\\Projects\\BDA\\aircraft_reliability\\data\\PM_train.xlsx")
df_truth = pd.read_excel("D:\\Projects\\BDA\\aircraft_reliability\\data\\PM_truth.xlsx")

# %%
df_merged = pd.merge(df, df_truth, on='id')
df_merged
# Out:
#        id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0       1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70
# 1       1      2    0.0019   -0.0003       100  518.67  642.15  1591.82
# 2       1      3   -0.0043    0.0003       100  518.67  642.35  1587.99
# 3       1      4    0.0007    0.0000       100  518.67  642.35  1582.79
# 4       1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85
# ...    ..    ...       ...       ...       ...     ...     ...      ...
# 20426  99    181   -0.0015   -0.0001       100  518.67  643.72  1600.39
# 20427  99    182   -0.0027   -0.0003       100  518.67  643.52  1605.33
# 20428  99    183   -0.0031   -0.0003       100  518.67  643.96  1606.95
# 20429  99    184   -0.0010   -0.0001       100  518.67  644.10  1600.20
# 20430  99    185   -0.0019   -0.0004       100  518.67  643.93  1598.42
#
#             s4     s5  ...      s13      s14     s15   s16  s17   s18  s19  \
# 0      1400.60  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100
# 1      1403.14  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100
# 2      1404.20  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100
# 3      1401.87  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100
# 4      1406.22  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100
# ...        ...    ...  ...      ...      ...     ...   ...  ...   ...  ...
# 20426  1428.03  14.62  ...  2388.29  8123.55  8.4885  0.03  396  2388  100
# 20427  1430.32  14.62  ...  2388.27  8130.99  8.5124  0.03  393  2388  100
# 20428  1427.90  14.62  ...  2388.31  8126.90  8.5374  0.03  395  2388  100
# 20429  1436.54  14.62  ...  2388.33  8125.66  8.5592  0.03  395  2388  100
# 20430  1421.56  14.62  ...  2388.24  8127.53  8.5425  0.03  397  2388  100
#
#          s20      s21  more
# 0      39.06  23.4190    98
# 1      39.00  23.4236    98
# 2      38.95  23.3442    98
# 3      38.88  23.3739    98
# 4      38.90  23.4044    98
# ...      ...      ...   ...
# 20426  38.50  23.0425    20
# 20427  38.39  22.9674    20
# 20428  38.57  23.1440    20
# 20429  38.45  23.0478    20
# 20430  38.49  23.1931    20
#
# [20431 rows x 27 columns]

# %%
# Step 1: Get the maximum cycle for each engine
max_cycle_per_engine = df.groupby('id')['cycle'].max().reset_index()
max_cycle_per_engine.columns = ['id', 'max_cycle']

# Step 2: Merge the maximum cycle with the df_truth to get the actual failure cycle
df_merged = pd.merge(max_cycle_per_engine, df_truth, on='id')

# Step 3: Calculate the actual failure cycle (when engine will fail)
df_merged['failure_cycle'] = df_merged['max_cycle'] + df_merged['more']

# Step 4: Merge this back with the main DataFrame to compute remaining cycles
df = pd.merge(df, df_merged[['id', 'failure_cycle']], on='id')

# Step 5: Calculate remaining cycles for each row by subtracting the current cycle from the failure cycle
df['remaining_cycles'] = df['failure_cycle'] - df['cycle']
df = df.drop('failure_cycle',axis=1)

# %%
df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000       100  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s13      s14     s15   s16  s17   s18  s19    s20      s21  \
# 0  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100  39.06  23.4190
# 1  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100  39.00  23.4236
# 2  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100  38.95  23.3442
# 3  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100  38.88  23.3739
# 4  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100  38.90  23.4044
#
#    remaining_cycles
# 0               289
# 1               288
# 2               287
# 3               286
# 4               285
#
# [5 rows x 27 columns]

# %%
# Assuming `df` is the provided DataFrame
# Split engines into train and test ensuring no overlap of engine IDs
engine_ids = df['id'].unique()
train_ids, test_ids = train_test_split(engine_ids, test_size=0.3, random_state=42)
train_ids,val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)
# Create train and test sets
train_df = df[df['id'].isin(train_ids)].reset_index(drop=True)
test_df = df[df['id'].isin(test_ids)].reset_index(drop=True)
val_df = df[df['id'].isin(val_ids)].reset_index(drop=True)

# %%
# def create_sequences(df, sequence_length=50):
#     X_seq, y_seq = [], []
#     for engine_id, group in df.groupby('id'):
#         # Ensure the group is sorted by cycle
#         group = group.sort_values('cycle')
#         # Create sequences
#         for start in range(len(group) - sequence_length):
#             end = start + sequence_length
#             sequence = group.iloc[start:end]
#             X_seq.append(sequence[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
#             y_seq.append(sequence['remaining_cycles'].values[-1])
#     return np.array(X_seq), np.array(y_seq)

# %%
def create_sequences_2(df, window_size=50):
    X_row_seq, y_row_seq = [], []
    X_window_seq, y_window_seq = [], []
    
    for engine_id, group in df.groupby('id'):
        # Ensure the group is sorted by cycle
        group = group.sort_values('cycle')
        
        # Row-wise sequence (each row as a single sequence)
        for _, row in group.iterrows():
            # Append each row as a sequence of length 1 for row-wise model
            X_row_seq.append(row[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
            y_row_seq.append(row['remaining_cycles'])
        
        # Sliding window sequence
        for start in range(len(group) - window_size + 1):
            end = start + window_size
            sequence = group.iloc[start:end]
            X_window_seq.append(sequence[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
            y_window_seq.append(sequence['remaining_cycles'].values[-1])  # Target is the RUL of the last cycle in window
    
    # Convert to numpy arrays
    X_row_seq = np.array(X_row_seq).reshape(-1, 1, len(X_row_seq[0]))  # Shape (num_rows, 1, num_features)
    y_row_seq = np.array(y_row_seq)
    X_window_seq = np.array(X_window_seq)  # Shape (num_windows, window_size, num_features)
    y_window_seq = np.array(y_window_seq)
    
    # Debugging output for shape verification
    print(f"Shape of X_row_seq: {X_row_seq.shape}")  # Should be (num_rows, 1, num_features)
    print(f"Shape of y_row_seq: {y_row_seq.shape}")  # Should be (num_rows,)
    print(f"Shape of X_window_seq: {X_window_seq.shape}")  # Should be (num_windows, window_size, num_features)
    print(f"Shape of y_window_seq: {y_window_seq.shape}")  # Should be (num_windows,)
    
    return X_row_seq, y_row_seq, X_window_seq, y_window_seq

# %%
window_size=5

# %%
xtrain_single, ytrain_single, xtrain_window, ytrain_window = create_sequences_2(train_df,window_size=window_size)
# Out:
# Shape of X_row_seq: (11433, 1, 24)
# Shape of y_row_seq: (11433,)
# Shape of X_window_seq: (11213, 5, 24)
# Shape of y_window_seq: (11213,)

# %%
xtest_single,ytest_single,xtest_window,ytest_window = create_sequences_2(test_df,window_size=window_size)
# Out:
# Shape of X_row_seq: (6061, 1, 24)
# Shape of y_row_seq: (6061,)
# Shape of X_window_seq: (5941, 5, 24)
# Shape of y_window_seq: (5941,)

# %%
xval_single,yval_single,xval_window,yval_window = create_sequences_2(val_df,window_size=window_size)
# Out:
# Shape of X_row_seq: (2937, 1, 24)
# Shape of y_row_seq: (2937,)
# Shape of X_window_seq: (2881, 5, 24)
# Shape of y_window_seq: (2881,)

# %%
#train test val of single

num_features = xtrain_single.shape[2]
scaler = StandardScaler()
Xtrain_reshaped = xtrain_single.reshape(-1, num_features)
X_train_scaled = scaler.fit_transform(Xtrain_reshaped)
Xtrain_scaled_single = X_train_scaled.reshape(xtrain_single.shape)

X_test_reshaped = xtest_single.reshape(-1, num_features)
X_test_scaled = scaler.transform(X_test_reshaped)  # Only transform on test data
Xtest_scaled_single = X_test_scaled.reshape(xtest_single.shape)

X_val_reshaped = xval_single.reshape(-1, num_features)
X_val_scaled = scaler.transform(X_val_reshaped)  # Only transform on test data
Xval_scaled_single = X_val_scaled.reshape(xval_single.shape)

# %%
#train test val of window

scaler = StandardScaler()
Xtrain_reshaped = xtrain_window.reshape(-1, num_features)
X_train_scaled = scaler.fit_transform(Xtrain_reshaped)
Xtrain_scaled_window = X_train_scaled.reshape(xtrain_window.shape)

X_test_reshaped = xtest_window.reshape(-1, num_features)
X_test_scaled = scaler.transform(X_test_reshaped)  # Only transform on test data
Xtest_scaled_window = X_test_scaled.reshape(xtest_window.shape)

X_val_reshaped = xval_window.reshape(-1, num_features)
X_val_scaled = scaler.transform(X_val_reshaped)  # Only transform on test data
Xval_scaled_window = X_val_scaled.reshape(xval_window.shape)

# %%
# Count the number of unique engines in train and test sets
num_train_engines = train_df['id'].nunique()
num_test_engines = test_df['id'].nunique()

print(f"Number of engines in training set: {num_train_engines}")
print(f"Number of engines in test set: {num_test_engines}")

# Sum the cycles per engine
train_cycles_per_engine = train_df.groupby('id').size()
test_cycles_per_engine = test_df.groupby('id').size()

print(f"Total cycles in training set: {train_cycles_per_engine.sum()}")
print(f"Total cycles in test set: {test_cycles_per_engine.sum()}")

# Optional: Check average cycles per engine
print(f"Average cycles per engine in training set: {train_cycles_per_engine.mean()}")
print(f"Average cycles per engine in test set: {test_cycles_per_engine.mean()}")
# Out:
# Number of engines in training set: 55
# Number of engines in test set: 30
# Total cycles in training set: 11433
# Total cycles in test set: 6061
# Average cycles per engine in training set: 207.87272727272727
# Average cycles per engine in test set: 202.03333333333333

# %%
single_model = Sequential([
    SimpleRNN(128, input_shape=(1, num_features), activation='relu', return_sequences=True),
    Dropout(0.2),
    SimpleRNN(64, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)
])
single_model.compile(optimizer=Adam(learning_rate=0.0001),loss='mean_absolute_error')

# %%
# Train the model
single_history = single_model.fit(Xtrain_scaled_single, ytrain_single,
                    validation_data=(Xval_scaled_single, yval_single),
                    epochs=200, batch_size=64,
                    callbacks=tf.keras.callbacks.EarlyStopping(patience=10,monitor='val_loss'))
# Out:
# Epoch 1/200
# 179/179 [==============================] - 3s 6ms/step - loss: 183.0501 - val_loss: 193.2642
# Epoch 2/200
# 179/179 [==============================] - 1s 4ms/step - loss: 177.0390 - val_loss: 181.8307
# Epoch 3/200
# 179/179 [==============================] - 1s 4ms/step - loss: 156.1597 - val_loss: 151.0387
# Epoch 4/200
# 179/179 [==============================] - 1s 4ms/step - loss: 116.4890 - val_loss: 108.7951
# Epoch 5/200
# 179/179 [==============================] - 1s 4ms/step - loss: 90.2178 - val_loss: 95.4688
# Epoch 6/200
# 179/179 [==============================] - 1s 4ms/step - loss: 84.3458 - val_loss: 89.3438
# Epoch 7/200
# 179/179 [==============================] - 1s 4ms/step - loss: 78.9882 - val_loss: 83.1911
# Epoch 8/200
# 179/179 [==============================] - 1s 4ms/step - loss: 72.8816 - val_loss: 76.9363
# Epoch 9/200
# 179/179 [==============================] - 1s 4ms/step - loss: 67.3650 - val_loss: 72.2540
# Epoch 10/200
# 179/179 [==============================] - 1s 4ms/step - loss: 62.9306 - val_loss: 68.8786
# Epoch 11/200
# 179/179 [==============================] - 1s 4ms/step - loss: 60.0131 - val_loss: 66.9173
# Epoch 12/200
# 179/179 [==============================] - 1s 4ms/step - loss: 57.5714 - val_loss: 65.6443
# Epoch 13/200
# 179/179 [==============================] - 1s 4ms/step - loss: 56.3078 - val_loss: 64.8762
# Epoch 14/200
# 179/179 [==============================] - 1s 4ms/step - loss: 55.1059 - val_loss: 64.3350
# Epoch 15/200
# 179/179 [==============================] - 1s 4ms/step - loss: 54.3062 - val_loss: 63.7938
# Epoch 16/200
# 179/179 [==============================] - 1s 4ms/step - loss: 53.9387 - val_loss: 63.3047
# Epoch 17/200
# 179/179 [==============================] - 1s 4ms/step - loss: 53.2800 - val_loss: 62.8947
# Epoch 18/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.9280 - val_loss: 62.7844
# Epoch 19/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.6190 - val_loss: 62.6576
# Epoch 20/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.2501 - val_loss: 62.4599
# Epoch 21/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.1265 - val_loss: 62.1860
# Epoch 22/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.1959 - val_loss: 62.3532
# Epoch 23/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.8629 - val_loss: 61.9985
# Epoch 24/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.6857 - val_loss: 61.8711
# Epoch 25/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.6652 - val_loss: 61.9464
# Epoch 26/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.2637 - val_loss: 61.5660
# Epoch 27/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.3738 - val_loss: 61.7754
# Epoch 28/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.2118 - val_loss: 61.5970
# Epoch 29/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.2550 - val_loss: 61.4375
# Epoch 30/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.9782 - val_loss: 61.4161
# Epoch 31/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.8041 - val_loss: 61.2778
# Epoch 32/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.7786 - val_loss: 61.1873
# Epoch 33/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.9038 - val_loss: 61.0810
# Epoch 34/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.7083 - val_loss: 61.2268
# Epoch 35/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.8099 - val_loss: 60.9835
# Epoch 36/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.7440 - val_loss: 61.2656
# Epoch 37/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.5269 - val_loss: 61.1233
# Epoch 38/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.5445 - val_loss: 60.8018
# Epoch 39/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.6031 - val_loss: 60.9370
# Epoch 40/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.3882 - val_loss: 61.1815
# Epoch 41/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.4445 - val_loss: 60.8490
# Epoch 42/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.2794 - val_loss: 61.2498
# Epoch 43/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.1456 - val_loss: 60.7478
# Epoch 44/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.2523 - val_loss: 61.1450
# Epoch 45/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.2306 - val_loss: 60.9040
# Epoch 46/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.0520 - val_loss: 60.6568
# Epoch 47/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.0705 - val_loss: 60.7499
# Epoch 48/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.1778 - val_loss: 61.0305
# Epoch 49/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.9784 - val_loss: 60.9858
# Epoch 50/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.1202 - val_loss: 60.4803
# Epoch 51/200
# 179/179 [==============================] - 1s 4ms/step - loss: 50.0072 - val_loss: 61.1244
# Epoch 52/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.9633 - val_loss: 60.5828
# Epoch 53/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.8957 - val_loss: 60.9859
# Epoch 54/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.7810 - val_loss: 60.7448
# Epoch 55/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.8204 - val_loss: 60.5457
# Epoch 56/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.7342 - val_loss: 60.5064
# Epoch 57/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.8199 - val_loss: 60.6624
# Epoch 58/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.7314 - val_loss: 60.5574
# Epoch 59/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.6913 - val_loss: 60.4182
# Epoch 60/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.7979 - val_loss: 60.2749
# Epoch 61/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.4753 - val_loss: 60.2579
# Epoch 62/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.6342 - val_loss: 60.6299
# Epoch 63/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.7031 - val_loss: 60.1427
# Epoch 64/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.5996 - val_loss: 60.4092
# Epoch 65/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.5443 - val_loss: 60.4467
# Epoch 66/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.1690 - val_loss: 60.4004
# Epoch 67/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.3922 - val_loss: 60.3941
# Epoch 68/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.5628 - val_loss: 60.2751
# Epoch 69/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.4486 - val_loss: 60.3610
# Epoch 70/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.3951 - val_loss: 60.0812
# Epoch 71/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.3868 - val_loss: 60.5956
# Epoch 72/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.3161 - val_loss: 60.0192
# Epoch 73/200
# 179/179 [==============================] - 1s 4ms/step - loss: 48.9888 - val_loss: 60.2529
# Epoch 74/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.2243 - val_loss: 60.2494
# Epoch 75/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.0836 - val_loss: 60.3500
# Epoch 76/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.1233 - val_loss: 60.6280
# Epoch 77/200
# 179/179 [==============================] - 1s 4ms/step - loss: 48.9789 - val_loss: 60.4057
# Epoch 78/200
# 179/179 [==============================] - 1s 4ms/step - loss: 49.0994 - val_loss: 60.0896
# Epoch 79/200
# 179/179 [==============================] - 1s 4ms/step - loss: 48.9388 - val_loss: 60.5446
# Epoch 80/200
# 179/179 [==============================] - 1s 4ms/step - loss: 48.9865 - val_loss: 60.3818
# Epoch 81/200
# 179/179 [==============================] - 1s 4ms/step - loss: 48.8827 - val_loss: 60.1395
# Epoch 82/200
# 179/179 [==============================] - 1s 4ms/step - loss: 48.8192 - val_loss: 60.3485

# %%
window_len = window_size

window_model = Sequential([
    SimpleRNN(256, input_shape=(window_size, num_features), activation='relu', return_sequences=True),
    Dropout(0.2),
    SimpleRNN(64, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)
])

window_model.compile(optimizer=Adam(learning_rate=0.0001),loss='mae')

# %%
# Train the model
window_history = window_model.fit(Xtrain_scaled_window, ytrain_window,
                                  validation_data=(Xval_scaled_window, yval_window),
                    epochs=100, batch_size=64,
                    callbacks=tf.keras.callbacks.EarlyStopping(patience=15,monitor='val_loss'))
# Out:
# Epoch 1/100
# 176/176 [==============================] - 4s 10ms/step - loss: 123.3364 - val_loss: 72.2684
# Epoch 2/100
# 176/176 [==============================] - 1s 8ms/step - loss: 58.2313 - val_loss: 64.5495
# Epoch 3/100
# 176/176 [==============================] - 1s 8ms/step - loss: 52.8114 - val_loss: 65.0414
# Epoch 4/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.1680 - val_loss: 61.1540
# Epoch 5/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.3372 - val_loss: 64.1184
# Epoch 6/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.0645 - val_loss: 60.5314
# Epoch 7/100
# 176/176 [==============================] - 1s 8ms/step - loss: 49.4172 - val_loss: 60.8869
# Epoch 8/100
# 176/176 [==============================] - 1s 8ms/step - loss: 49.1067 - val_loss: 60.9982
# Epoch 9/100
# 176/176 [==============================] - 1s 8ms/step - loss: 49.0078 - val_loss: 61.5217
# Epoch 10/100
# 176/176 [==============================] - 1s 8ms/step - loss: 48.4053 - val_loss: 61.1447
# Epoch 11/100
# 176/176 [==============================] - 1s 8ms/step - loss: 48.3997 - val_loss: 59.6794
# Epoch 12/100
# 176/176 [==============================] - 1s 8ms/step - loss: 48.1641 - val_loss: 60.5154
# Epoch 13/100
# 176/176 [==============================] - 1s 8ms/step - loss: 47.9848 - val_loss: 61.4251
# Epoch 14/100
# 176/176 [==============================] - 1s 8ms/step - loss: 47.6243 - val_loss: 62.6069
# Epoch 15/100
# 176/176 [==============================] - 1s 8ms/step - loss: 47.6190 - val_loss: 60.6442
# Epoch 16/100
# 176/176 [==============================] - 1s 8ms/step - loss: 47.3551 - val_loss: 59.7916
# Epoch 17/100
# 176/176 [==============================] - 2s 9ms/step - loss: 47.1499 - val_loss: 63.3158
# Epoch 18/100
# 176/176 [==============================] - 1s 8ms/step - loss: 47.1860 - val_loss: 62.3156
# Epoch 19/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.9353 - val_loss: 60.6724
# Epoch 20/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.6753 - val_loss: 61.7599
# Epoch 21/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.6094 - val_loss: 61.5361
# Epoch 22/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.4293 - val_loss: 62.1105
# Epoch 23/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.3213 - val_loss: 61.2929
# Epoch 24/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.1204 - val_loss: 60.4741
# Epoch 25/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.1281 - val_loss: 61.0168
# Epoch 26/100
# 176/176 [==============================] - 1s 8ms/step - loss: 46.0481 - val_loss: 60.4873

# %%
# Plotting function
def plot_loss(history, title,lim=(None,None)):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(title)
    plt.legend()
    plt.ylim(lim)
    plt.grid(True)
    plt.show()

# Plot for individual row-wise model
plot_loss(single_history, 'Individual Row-wise Model Loss',(45,70))

# %%
plot_loss(window_history,'Window Model Loss',(10,80))

# %%
# Adjusted evaluation function
def evaluate_model(model, X_test, y_test,type):
    predictions = model.predict(X_test)
    if predictions.shape[0] != y_test.shape[0]:
        # Trimming to the minimum size for consistency
        min_len = min(predictions.shape[0], y_test.shape[0])
        predictions = predictions[:min_len]
        y_test = y_test[:min_len]
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    mae = mean_absolute_error(y_test, predictions)
    print(f"{type} Model Evaluation - RMSE: {rmse:.2f}, MAE: {mae:.2f}")
    return predictions, rmse, mae

# %%
def get_combined_predictions(pred_single, pred_window):
    """
    Combines predictions from single-model and window-model predictions.

    Args:
        pred_single (np.array): Predictions from the single-model.
        pred_window (np.array): Predictions from the window-model.

    Returns:
        combined_predictions (np.array): Averaged predictions.
    """
    # Ensure the predictions are reshaped to (n_samples, 1) for averaging
    pred_single = np.array(pred_single).reshape(-1, 1)
    pred_window = np.array(pred_window).reshape(-1, 1)
    
    # Average the predictions
    combined_predictions = (pred_single + pred_window) / 2
    return combined_predictions

# %%
# Now update the combined evaluation to use trimmed predictions
def evaluate_combined_model(pred_single, pred_window, y_test):
    # Trim both predictions and y_test to the minimum shared length
    min_len = min(len(pred_single), len(pred_window), len(y_test))
    pred_single, pred_window, y_test = pred_single[:min_len], pred_window[:min_len], y_test[:min_len]

    # Get combined predictions
    combined_predictions = (pred_single + pred_window) / 2
    rmse = np.sqrt(mean_squared_error(y_test, combined_predictions))
    mae = mean_absolute_error(y_test, combined_predictions)
    print(f"Combined Model Evaluation - RMSE: {rmse:.2f}, MAE: {mae:.2f}")
    return combined_predictions, rmse, mae

# %%
# Get predictions and evaluate each model individually
pred_single, rmse_single, mae_single = evaluate_model(single_model, Xtest_scaled_single, ytest_single,'single')
pred_window, rmse_window, mae_window = evaluate_model(window_model, Xtest_scaled_window, ytest_window,'window')

# Evaluate combined predictions
combined_predictions, rmse_combined, mae_combined = evaluate_combined_model(pred_single, pred_window, ytest_single)
# Out:
# 190/190 [==============================] - 1s 2ms/step
# single Model Evaluation - RMSE: 59.12, MAE: 45.81
# 186/186 [==============================] - 1s 3ms/step
# window Model Evaluation - RMSE: 60.46, MAE: 47.24
# Combined Model Evaluation - RMSE: 69.59, MAE: 55.71

# %%
Xtest_scaled_window.shape
# Out:
# (5941, 5, 24)
