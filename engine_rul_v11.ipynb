# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed,SimpleRNN,Dropout,GRU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_excel("D:\\Projects\\BDA\\aircraft_reliability\\data\\PM_train.xlsx")
df_truth = pd.read_excel("D:\\Projects\\BDA\\aircraft_reliability\\data\\PM_truth.xlsx")

# %%
df_merged = pd.merge(df, df_truth, on='id')
df_merged
# Out:
#        id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0       1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70
# 1       1      2    0.0019   -0.0003       100  518.67  642.15  1591.82
# 2       1      3   -0.0043    0.0003       100  518.67  642.35  1587.99
# 3       1      4    0.0007    0.0000       100  518.67  642.35  1582.79
# 4       1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85
# ...    ..    ...       ...       ...       ...     ...     ...      ...
# 20426  99    181   -0.0015   -0.0001       100  518.67  643.72  1600.39
# 20427  99    182   -0.0027   -0.0003       100  518.67  643.52  1605.33
# 20428  99    183   -0.0031   -0.0003       100  518.67  643.96  1606.95
# 20429  99    184   -0.0010   -0.0001       100  518.67  644.10  1600.20
# 20430  99    185   -0.0019   -0.0004       100  518.67  643.93  1598.42
#
#             s4     s5  ...      s13      s14     s15   s16  s17   s18  s19  \
# 0      1400.60  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100
# 1      1403.14  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100
# 2      1404.20  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100
# 3      1401.87  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100
# 4      1406.22  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100
# ...        ...    ...  ...      ...      ...     ...   ...  ...   ...  ...
# 20426  1428.03  14.62  ...  2388.29  8123.55  8.4885  0.03  396  2388  100
# 20427  1430.32  14.62  ...  2388.27  8130.99  8.5124  0.03  393  2388  100
# 20428  1427.90  14.62  ...  2388.31  8126.90  8.5374  0.03  395  2388  100
# 20429  1436.54  14.62  ...  2388.33  8125.66  8.5592  0.03  395  2388  100
# 20430  1421.56  14.62  ...  2388.24  8127.53  8.5425  0.03  397  2388  100
#
#          s20      s21  more
# 0      39.06  23.4190    98
# 1      39.00  23.4236    98
# 2      38.95  23.3442    98
# 3      38.88  23.3739    98
# 4      38.90  23.4044    98
# ...      ...      ...   ...
# 20426  38.50  23.0425    20
# 20427  38.39  22.9674    20
# 20428  38.57  23.1440    20
# 20429  38.45  23.0478    20
# 20430  38.49  23.1931    20
#
# [20431 rows x 27 columns]

# %%
# Step 1: Get the maximum cycle for each engine
max_cycle_per_engine = df.groupby('id')['cycle'].max().reset_index()
max_cycle_per_engine.columns = ['id', 'max_cycle']

# Step 2: Merge the maximum cycle with the df_truth to get the actual failure cycle
df_merged = pd.merge(max_cycle_per_engine, df_truth, on='id')

# Step 3: Calculate the actual failure cycle (when engine will fail)
df_merged['failure_cycle'] = df_merged['max_cycle'] + df_merged['more']

# Step 4: Merge this back with the main DataFrame to compute remaining cycles
df = pd.merge(df, df_merged[['id', 'failure_cycle']], on='id')

# Step 5: Calculate remaining cycles for each row by subtracting the current cycle from the failure cycle
df['remaining_cycles'] = df['failure_cycle'] - df['cycle']
df = df.drop('failure_cycle',axis=1)

# %%
df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000       100  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s13      s14     s15   s16  s17   s18  s19    s20      s21  \
# 0  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100  39.06  23.4190
# 1  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100  39.00  23.4236
# 2  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100  38.95  23.3442
# 3  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100  38.88  23.3739
# 4  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100  38.90  23.4044
#
#    remaining_cycles
# 0               289
# 1               288
# 2               287
# 3               286
# 4               285
#
# [5 rows x 27 columns]

# %%
# Assuming `df` is the provided DataFrame
# Split engines into train and test ensuring no overlap of engine IDs
engine_ids = df['id'].unique()
train_ids, test_ids = train_test_split(engine_ids, test_size=0.3, random_state=42)
train_ids,val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)
# Create train and test sets
train_df = df[df['id'].isin(train_ids)].reset_index(drop=True)
test_df = df[df['id'].isin(test_ids)].reset_index(drop=True)
val_df = df[df['id'].isin(val_ids)].reset_index(drop=True)

# %%
def create_sequences_2(df, window_size=50):
    X_row_seq, y_row_seq = [], []
    X_window_seq, y_window_seq = [], []
    
    for engine_id, group in df.groupby('id'):
        # Ensure the group is sorted by cycle
        group = group.sort_values('cycle')
        
        # Row-wise sequence (each row as a single sequence)
        for _, row in group.iterrows():
            # Append each row as a sequence of length 1 for row-wise model
            X_row_seq.append(row[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
            y_row_seq.append(row['remaining_cycles'])
        
        # Sliding window sequence
        for start in range(len(group) - window_size + 1):
            end = start + window_size
            sequence = group.iloc[start:end]
            X_window_seq.append(sequence[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
            y_window_seq.append(sequence['remaining_cycles'].values[-1])  # Target is the RUL of the last cycle in window
    
    # Convert to numpy arrays
    X_row_seq = np.array(X_row_seq).reshape(-1, 1, len(X_row_seq[0]))  # Shape (num_rows, 1, num_features)
    y_row_seq = np.array(y_row_seq)
    X_window_seq = np.array(X_window_seq)  # Shape (num_windows, window_size, num_features)
    y_window_seq = np.array(y_window_seq)
    
    # Debugging output for shape verification
    print(f"Shape of X_row_seq: {X_row_seq.shape}")  # Should be (num_rows, 1, num_features)
    print(f"Shape of y_row_seq: {y_row_seq.shape}")  # Should be (num_rows,)
    print(f"Shape of X_window_seq: {X_window_seq.shape}")  # Should be (num_windows, window_size, num_features)
    print(f"Shape of y_window_seq: {y_window_seq.shape}")  # Should be (num_windows,)
    
    return X_row_seq, y_row_seq, X_window_seq, y_window_seq

# %%
window_size=5

# %%
xtrain_single, ytrain_single, xtrain_window, ytrain_window = create_sequences_2(train_df,window_size=window_size)
# Out:
# Shape of X_row_seq: (11433, 1, 24)
# Shape of y_row_seq: (11433,)
# Shape of X_window_seq: (11213, 5, 24)
# Shape of y_window_seq: (11213,)

# %%
xtest_single,ytest_single,xtest_window,ytest_window = create_sequences_2(test_df,window_size=window_size)
# Out:
# Shape of X_row_seq: (6061, 1, 24)
# Shape of y_row_seq: (6061,)
# Shape of X_window_seq: (5941, 5, 24)
# Shape of y_window_seq: (5941,)

# %%
xval_single,yval_single,xval_window,yval_window = create_sequences_2(val_df,window_size=window_size)
# Out:
# Shape of X_row_seq: (2937, 1, 24)
# Shape of y_row_seq: (2937,)
# Shape of X_window_seq: (2881, 5, 24)
# Shape of y_window_seq: (2881,)

# %%
#train test val of single

num_features = xtrain_single.shape[2]
scaler = StandardScaler()
Xtrain_reshaped = xtrain_single.reshape(-1, num_features)
X_train_scaled = scaler.fit_transform(Xtrain_reshaped)
Xtrain_scaled_single = X_train_scaled.reshape(xtrain_single.shape)

X_test_reshaped = xtest_single.reshape(-1, num_features)
X_test_scaled = scaler.transform(X_test_reshaped)  # Only transform on test data
Xtest_scaled_single = X_test_scaled.reshape(xtest_single.shape)

X_val_reshaped = xval_single.reshape(-1, num_features)
X_val_scaled = scaler.transform(X_val_reshaped)  # Only transform on test data
Xval_scaled_single = X_val_scaled.reshape(xval_single.shape)

# %%
#train test val of window

scaler = StandardScaler()
Xtrain_reshaped = xtrain_window.reshape(-1, num_features)
X_train_scaled = scaler.fit_transform(Xtrain_reshaped)
Xtrain_scaled_window = X_train_scaled.reshape(xtrain_window.shape)

X_test_reshaped = xtest_window.reshape(-1, num_features)
X_test_scaled = scaler.transform(X_test_reshaped)  # Only transform on test data
Xtest_scaled_window = X_test_scaled.reshape(xtest_window.shape)

X_val_reshaped = xval_window.reshape(-1, num_features)
X_val_scaled = scaler.transform(X_val_reshaped)  # Only transform on test data
Xval_scaled_window = X_val_scaled.reshape(xval_window.shape)

# %%
# Count the number of unique engines in train and test sets
num_train_engines = train_df['id'].nunique()
num_test_engines = test_df['id'].nunique()

print(f"Number of engines in training set: {num_train_engines}")
print(f"Number of engines in test set: {num_test_engines}")

# Sum the cycles per engine
train_cycles_per_engine = train_df.groupby('id').size()
test_cycles_per_engine = test_df.groupby('id').size()

print(f"Total cycles in training set: {train_cycles_per_engine.sum()}")
print(f"Total cycles in test set: {test_cycles_per_engine.sum()}")

# Optional: Check average cycles per engine
print(f"Average cycles per engine in training set: {train_cycles_per_engine.mean()}")
print(f"Average cycles per engine in test set: {test_cycles_per_engine.mean()}")
# Out:
# Number of engines in training set: 55
# Number of engines in test set: 30
# Total cycles in training set: 11433
# Total cycles in test set: 6061
# Average cycles per engine in training set: 207.87272727272727
# Average cycles per engine in test set: 202.03333333333333

# %%
single_model = Sequential([
    SimpleRNN(128, input_shape=(1, num_features), return_sequences=False),  # LSTM layer for row-level sequences
    Dropout(0.2),  # Regularization to avoid overfitting
    Dense(64, activation='relu'),  # Fully connected layer for feature extraction
    Dropout(0.2),  # Regularization
    Dense(1)  # Output layer (RUL prediction)
])
single_model.compile(optimizer=Adam(learning_rate=0.0001),loss='mse')

# %%
# Train the model
single_history = single_model.fit(Xtrain_scaled_single, ytrain_single,
                    validation_data=(Xval_scaled_single, yval_single),
                    epochs=200, batch_size=64,
                    callbacks=tf.keras.callbacks.EarlyStopping(patience=10,monitor='val_loss'))
# Out:
# Epoch 1/200
# 179/179 [==============================] - 2s 5ms/step - loss: 183.4339 - val_loss: 194.2030
# Epoch 2/200
# 179/179 [==============================] - 1s 4ms/step - loss: 180.5586 - val_loss: 189.9300
# Epoch 3/200
# 179/179 [==============================] - 1s 4ms/step - loss: 174.2675 - val_loss: 181.6938
# Epoch 4/200
# 179/179 [==============================] - 1s 4ms/step - loss: 163.6964 - val_loss: 169.6912
# Epoch 5/200
# 179/179 [==============================] - 1s 4ms/step - loss: 149.1626 - val_loss: 155.0159
# Epoch 6/200
# 179/179 [==============================] - 1s 4ms/step - loss: 132.3946 - val_loss: 139.1256
# Epoch 7/200
# 179/179 [==============================] - 1s 4ms/step - loss: 114.7168 - val_loss: 123.4925
# Epoch 8/200
# 179/179 [==============================] - 1s 4ms/step - loss: 98.4188 - val_loss: 109.8248
# Epoch 9/200
# 179/179 [==============================] - 1s 4ms/step - loss: 85.5217 - val_loss: 99.8663
# Epoch 10/200
# 179/179 [==============================] - 1s 4ms/step - loss: 78.2734 - val_loss: 94.3665
# Epoch 11/200
# 179/179 [==============================] - 1s 4ms/step - loss: 74.2961 - val_loss: 91.4819
# Epoch 12/200
# 179/179 [==============================] - 1s 4ms/step - loss: 72.4207 - val_loss: 89.9809
# Epoch 13/200
# 179/179 [==============================] - 1s 4ms/step - loss: 71.7095 - val_loss: 89.0039
# Epoch 14/200
# 179/179 [==============================] - 1s 3ms/step - loss: 70.8924 - val_loss: 88.3749
# Epoch 15/200
# 179/179 [==============================] - 1s 4ms/step - loss: 70.4178 - val_loss: 87.4997
# Epoch 16/200
# 179/179 [==============================] - 1s 4ms/step - loss: 69.5423 - val_loss: 86.9498
# Epoch 17/200
# 179/179 [==============================] - 1s 3ms/step - loss: 68.9177 - val_loss: 86.5369
# Epoch 18/200
# 179/179 [==============================] - 1s 3ms/step - loss: 68.2986 - val_loss: 86.0700
# Epoch 19/200
# 179/179 [==============================] - 1s 4ms/step - loss: 68.0012 - val_loss: 85.6199
# Epoch 20/200
# 179/179 [==============================] - 1s 4ms/step - loss: 67.5746 - val_loss: 84.9547
# Epoch 21/200
# 179/179 [==============================] - 1s 4ms/step - loss: 67.2858 - val_loss: 84.4169
# Epoch 22/200
# 179/179 [==============================] - 1s 4ms/step - loss: 66.6962 - val_loss: 84.0473
# Epoch 23/200
# 179/179 [==============================] - 1s 4ms/step - loss: 66.0324 - val_loss: 83.4922
# Epoch 24/200
# 179/179 [==============================] - 1s 3ms/step - loss: 65.9992 - val_loss: 83.0574
# Epoch 25/200
# 179/179 [==============================] - 1s 4ms/step - loss: 65.4207 - val_loss: 82.2681
# Epoch 26/200
# 179/179 [==============================] - 1s 4ms/step - loss: 65.1020 - val_loss: 81.8348
# Epoch 27/200
# 179/179 [==============================] - 1s 4ms/step - loss: 64.8798 - val_loss: 81.3172
# Epoch 28/200
# 179/179 [==============================] - 1s 3ms/step - loss: 64.3281 - val_loss: 80.7085
# Epoch 29/200
# 179/179 [==============================] - 1s 4ms/step - loss: 63.8204 - val_loss: 80.2253
# Epoch 30/200
# 179/179 [==============================] - 1s 4ms/step - loss: 63.3543 - val_loss: 79.5727
# Epoch 31/200
# 179/179 [==============================] - 1s 4ms/step - loss: 63.1391 - val_loss: 78.8268
# Epoch 32/200
# 179/179 [==============================] - 1s 4ms/step - loss: 62.6600 - val_loss: 78.2757
# Epoch 33/200
# 179/179 [==============================] - 1s 4ms/step - loss: 62.3597 - val_loss: 77.6018
# Epoch 34/200
# 179/179 [==============================] - 1s 4ms/step - loss: 61.8614 - val_loss: 77.0801
# Epoch 35/200
# 179/179 [==============================] - 1s 4ms/step - loss: 61.2319 - val_loss: 76.3359
# Epoch 36/200
# 179/179 [==============================] - 1s 4ms/step - loss: 61.0566 - val_loss: 75.7423
# Epoch 37/200
# 179/179 [==============================] - 1s 4ms/step - loss: 60.4311 - val_loss: 74.9193
# Epoch 38/200
# 179/179 [==============================] - 1s 4ms/step - loss: 59.9191 - val_loss: 74.1016
# Epoch 39/200
# 179/179 [==============================] - 1s 4ms/step - loss: 59.6324 - val_loss: 73.3809
# Epoch 40/200
# 179/179 [==============================] - 1s 4ms/step - loss: 59.2530 - val_loss: 72.6949
# Epoch 41/200
# 179/179 [==============================] - 1s 3ms/step - loss: 58.4618 - val_loss: 71.9208
# Epoch 42/200
# 179/179 [==============================] - 1s 4ms/step - loss: 58.1571 - val_loss: 71.1776
# Epoch 43/200
# 179/179 [==============================] - 1s 4ms/step - loss: 57.5959 - val_loss: 70.3378
# Epoch 44/200
# 179/179 [==============================] - 1s 3ms/step - loss: 57.3396 - val_loss: 69.5809
# Epoch 45/200
# 179/179 [==============================] - 1s 4ms/step - loss: 56.8821 - val_loss: 68.6964
# Epoch 46/200
# 179/179 [==============================] - 1s 4ms/step - loss: 56.4257 - val_loss: 68.0667
# Epoch 47/200
# 179/179 [==============================] - 1s 3ms/step - loss: 55.8963 - val_loss: 67.3540
# Epoch 48/200
# 179/179 [==============================] - 1s 4ms/step - loss: 55.3859 - val_loss: 66.7444
# Epoch 49/200
# 179/179 [==============================] - 1s 4ms/step - loss: 55.3041 - val_loss: 66.0671
# Epoch 50/200
# 179/179 [==============================] - 1s 4ms/step - loss: 54.9677 - val_loss: 65.4731
# Epoch 51/200
# 179/179 [==============================] - 1s 4ms/step - loss: 54.5166 - val_loss: 64.9478
# Epoch 52/200
# 179/179 [==============================] - 1s 4ms/step - loss: 54.2723 - val_loss: 64.5869
# Epoch 53/200
# 179/179 [==============================] - 1s 4ms/step - loss: 54.2502 - val_loss: 63.9948
# Epoch 54/200
# 179/179 [==============================] - 1s 3ms/step - loss: 53.6595 - val_loss: 63.8734
# Epoch 55/200
# 179/179 [==============================] - 1s 4ms/step - loss: 53.8785 - val_loss: 63.6289
# Epoch 56/200
# 179/179 [==============================] - 1s 4ms/step - loss: 53.9260 - val_loss: 63.3624
# Epoch 57/200
# 179/179 [==============================] - 1s 4ms/step - loss: 53.1510 - val_loss: 63.2737
# Epoch 58/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.9418 - val_loss: 63.0110
# Epoch 59/200
# 179/179 [==============================] - 1s 4ms/step - loss: 53.1413 - val_loss: 63.1009
# Epoch 60/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.9227 - val_loss: 62.9843
# Epoch 61/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.9722 - val_loss: 62.7282
# Epoch 62/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.9065 - val_loss: 62.6501
# Epoch 63/200
# 179/179 [==============================] - 1s 4ms/step - loss: 53.0266 - val_loss: 62.5372
# Epoch 64/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.8754 - val_loss: 62.7852
# Epoch 65/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.5292 - val_loss: 62.5964
# Epoch 66/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.7711 - val_loss: 62.5778
# Epoch 67/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.8687 - val_loss: 62.6753
# Epoch 68/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.8944 - val_loss: 62.5897
# Epoch 69/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.3106 - val_loss: 62.3968
# Epoch 70/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.0050 - val_loss: 62.5086
# Epoch 71/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.0435 - val_loss: 62.3754
# Epoch 72/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.1975 - val_loss: 62.6030
# Epoch 73/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.3229 - val_loss: 62.3905
# Epoch 74/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.8850 - val_loss: 62.5287
# Epoch 75/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.8148 - val_loss: 62.4805
# Epoch 76/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.9223 - val_loss: 62.6120
# Epoch 77/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.3122 - val_loss: 62.4439
# Epoch 78/200
# 179/179 [==============================] - 1s 4ms/step - loss: 52.2643 - val_loss: 62.7864
# Epoch 79/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.8577 - val_loss: 62.5599
# Epoch 80/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.8433 - val_loss: 62.7093
# Epoch 81/200
# 179/179 [==============================] - 1s 4ms/step - loss: 51.7826 - val_loss: 62.6187

# %%
window_model = Sequential([
    GRU(128, input_shape=(window_size, num_features), return_sequences=False),  # LSTM layer for window-level sequences
    Dropout(0.2),  # Regularization
    Dense(64, activation='relu'),  # Fully connected layer
    Dropout(0.2),  # Regularization
    Dense(1)  # Output layer (RUL prediction)
])

window_model.compile(optimizer=Adam(learning_rate=0.0001),loss='mse')

# %%
# Train the model
window_history = window_model.fit(Xtrain_scaled_window, ytrain_window,
                                  validation_data=(Xval_scaled_window, yval_window),
                    epochs=100, batch_size=64,
                    callbacks=tf.keras.callbacks.EarlyStopping(patience=15,monitor='val_loss'))
# Out:
# Epoch 1/100
# 176/176 [==============================] - 5s 11ms/step - loss: 179.6378 - val_loss: 187.3114
# Epoch 2/100
# 176/176 [==============================] - 1s 8ms/step - loss: 166.3840 - val_loss: 171.2661
# Epoch 3/100
# 176/176 [==============================] - 1s 7ms/step - loss: 148.9725 - val_loss: 153.2299
# Epoch 4/100
# 176/176 [==============================] - 1s 8ms/step - loss: 130.4756 - val_loss: 134.4261
# Epoch 5/100
# 176/176 [==============================] - 1s 7ms/step - loss: 111.7247 - val_loss: 116.8117
# Epoch 6/100
# 176/176 [==============================] - 1s 8ms/step - loss: 94.1495 - val_loss: 100.6666
# Epoch 7/100
# 176/176 [==============================] - 2s 9ms/step - loss: 78.4987 - val_loss: 87.1243
# Epoch 8/100
# 176/176 [==============================] - 1s 7ms/step - loss: 66.7629 - val_loss: 77.2666
# Epoch 9/100
# 176/176 [==============================] - 1s 8ms/step - loss: 59.1301 - val_loss: 71.5653
# Epoch 10/100
# 176/176 [==============================] - 1s 7ms/step - loss: 56.5080 - val_loss: 68.4465
# Epoch 11/100
# 176/176 [==============================] - 1s 7ms/step - loss: 54.8619 - val_loss: 67.1611
# Epoch 12/100
# 176/176 [==============================] - 1s 8ms/step - loss: 54.4082 - val_loss: 65.9503
# Epoch 13/100
# 176/176 [==============================] - 1s 7ms/step - loss: 54.1623 - val_loss: 65.7554
# Epoch 14/100
# 176/176 [==============================] - 1s 8ms/step - loss: 53.9588 - val_loss: 64.8806
# Epoch 15/100
# 176/176 [==============================] - 1s 7ms/step - loss: 53.4878 - val_loss: 64.9483
# Epoch 16/100
# 176/176 [==============================] - 1s 7ms/step - loss: 53.8660 - val_loss: 65.0205
# Epoch 17/100
# 176/176 [==============================] - 1s 8ms/step - loss: 52.9042 - val_loss: 64.9567
# Epoch 18/100
# 176/176 [==============================] - 1s 8ms/step - loss: 53.2110 - val_loss: 64.5398
# Epoch 19/100
# 176/176 [==============================] - 1s 7ms/step - loss: 53.5113 - val_loss: 64.3611
# Epoch 20/100
# 176/176 [==============================] - 1s 8ms/step - loss: 52.8400 - val_loss: 64.3671
# Epoch 21/100
# 176/176 [==============================] - 1s 7ms/step - loss: 52.8057 - val_loss: 64.1917
# Epoch 22/100
# 176/176 [==============================] - 1s 8ms/step - loss: 52.3690 - val_loss: 63.8401
# Epoch 23/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.9439 - val_loss: 63.7126
# Epoch 24/100
# 176/176 [==============================] - 1s 7ms/step - loss: 52.0741 - val_loss: 63.1947
# Epoch 25/100
# 176/176 [==============================] - 1s 8ms/step - loss: 52.0304 - val_loss: 63.2459
# Epoch 26/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.9297 - val_loss: 63.6487
# Epoch 27/100
# 176/176 [==============================] - 1s 7ms/step - loss: 51.9009 - val_loss: 62.1696
# Epoch 28/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.8772 - val_loss: 62.3539
# Epoch 29/100
# 176/176 [==============================] - 1s 7ms/step - loss: 51.7603 - val_loss: 62.7555
# Epoch 30/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.2973 - val_loss: 62.4543
# Epoch 31/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.6851 - val_loss: 61.9385
# Epoch 32/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.8849 - val_loss: 61.8229
# Epoch 33/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.3217 - val_loss: 62.1208
# Epoch 34/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.4054 - val_loss: 61.9924
# Epoch 35/100
# 176/176 [==============================] - 1s 7ms/step - loss: 51.5106 - val_loss: 61.9512
# Epoch 36/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.5036 - val_loss: 62.1412
# Epoch 37/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.6460 - val_loss: 61.8581
# Epoch 38/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.2693 - val_loss: 62.1662
# Epoch 39/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.0892 - val_loss: 61.9204
# Epoch 40/100
# 176/176 [==============================] - 1s 7ms/step - loss: 51.2040 - val_loss: 61.8409
# Epoch 41/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.4776 - val_loss: 61.8015
# Epoch 42/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.0274 - val_loss: 61.4071
# Epoch 43/100
# 176/176 [==============================] - 1s 7ms/step - loss: 51.2413 - val_loss: 61.3125
# Epoch 44/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.1797 - val_loss: 61.5101
# Epoch 45/100
# 176/176 [==============================] - 1s 7ms/step - loss: 50.4450 - val_loss: 61.6754
# Epoch 46/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.9079 - val_loss: 61.3979
# Epoch 47/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.8449 - val_loss: 61.4762
# Epoch 48/100
# 176/176 [==============================] - 1s 7ms/step - loss: 50.9966 - val_loss: 61.6470
# Epoch 49/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.0621 - val_loss: 62.0140
# Epoch 50/100
# 176/176 [==============================] - 1s 7ms/step - loss: 51.0074 - val_loss: 61.7083
# Epoch 51/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.8753 - val_loss: 61.6260
# Epoch 52/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.8358 - val_loss: 61.1722
# Epoch 53/100
# 176/176 [==============================] - 1s 7ms/step - loss: 50.8033 - val_loss: 61.6505
# Epoch 54/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.7806 - val_loss: 61.8913
# Epoch 55/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.0649 - val_loss: 61.4468
# Epoch 56/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.8322 - val_loss: 62.1587
# Epoch 57/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.6350 - val_loss: 62.1063
# Epoch 58/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.1775 - val_loss: 62.0438
# Epoch 59/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.9532 - val_loss: 62.7894
# Epoch 60/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.8826 - val_loss: 61.5310
# Epoch 61/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.9055 - val_loss: 62.2087
# Epoch 62/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.6393 - val_loss: 61.9868
# Epoch 63/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.8532 - val_loss: 62.0395
# Epoch 64/100
# 176/176 [==============================] - 1s 7ms/step - loss: 50.6745 - val_loss: 62.2529
# Epoch 65/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.6645 - val_loss: 62.0231
# Epoch 66/100
# 176/176 [==============================] - 1s 8ms/step - loss: 50.8013 - val_loss: 62.2467
# Epoch 67/100
# 176/176 [==============================] - 1s 8ms/step - loss: 51.0136 - val_loss: 61.9363

# %%
# Plotting function
def plot_loss(history, title,lim=(None,None)):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(title)
    plt.legend()
    plt.ylim(lim)
    plt.grid(True)
    plt.show()

# Plot for individual row-wise model
plot_loss(single_history, 'Individual Row-wise Model Loss')

# %%
plot_loss(window_history,'Window Model Loss',)

# %%
# Adjusted evaluation function
def evaluate_model(model, X_test, y_test,type):
    predictions = model.predict(X_test)
    if predictions.shape[0] != y_test.shape[0]:
        # Trimming to the minimum size for consistency
        min_len = min(predictions.shape[0], y_test.shape[0])
        predictions = predictions[:min_len]
        y_test = y_test[:min_len]
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    mae = mean_absolute_error(y_test, predictions)
    print(f"{type} Model Evaluation - RMSE: {rmse:.2f}, MAE: {mae:.2f}")
    return predictions, rmse, mae

# %%
def get_combined_predictions(pred_single, pred_window):
    """
    Combines predictions from single-model and window-model predictions.

    Args:
        pred_single (np.array): Predictions from the single-model.
        pred_window (np.array): Predictions from the window-model.

    Returns:
        combined_predictions (np.array): Averaged predictions.
    """
    # Ensure the predictions are reshaped to (n_samples, 1) for averaging
    pred_single = np.array(pred_single).reshape(-1, 1)
    pred_window = np.array(pred_window).reshape(-1, 1)
    
    # Average the predictions
    combined_predictions = (pred_single + pred_window) / 2
    return combined_predictions

# %%
# Now update the combined evaluation to use trimmed predictions
def evaluate_combined_model(pred_single, pred_window, y_test):
    # Trim both predictions and y_test to the minimum shared length
    min_len = min(len(pred_single), len(pred_window), len(y_test))
    pred_single, pred_window, y_test = pred_single[:min_len], pred_window[:min_len], y_test[:min_len]

    # Get combined predictions
    combined_predictions = (pred_single + pred_window) / 2
    rmse = np.sqrt(mean_squared_error(y_test, combined_predictions))
    mae = mean_absolute_error(y_test, combined_predictions)
    print(f"Combined Model Evaluation - RMSE: {rmse:.2f}, MAE: {mae:.2f}")
    return combined_predictions, rmse, mae

# %%
# Get predictions and evaluate each model individually
pred_single, rmse_single, mae_single = evaluate_model(single_model, Xtest_scaled_single, ytest_single,'single')
pred_window, rmse_window, mae_window = evaluate_model(window_model, Xtest_scaled_window, ytest_window,'window')

# Evaluate combined predictions
combined_predictions, rmse_combined, mae_combined = evaluate_combined_model(pred_single, pred_window, ytest_single)
# Out:
# 190/190 [==============================] - 0s 2ms/step
# single Model Evaluation - RMSE: 60.45, MAE: 46.98
# 186/186 [==============================] - 1s 3ms/step
# window Model Evaluation - RMSE: 58.86, MAE: 46.16
# Combined Model Evaluation - RMSE: 69.55, MAE: 55.89

# %%
Xtest_scaled_window.shape
# Out:
# (5941, 5, 24)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history, model_name="Model"):
    """
    Plots the training and validation loss and metric (e.g., RMSE) for each epoch.
    
    Parameters:
    - history: History object from model training.
    - model_name: Name of the model for labeling the plot.
    """
    # Plot loss
    plt.figure(figsize=(12, 5))
    
    # Plot training & validation loss values
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_name} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    # Plot training & validation RMSE/MAE values if available
    if 'rmse' in history.history:
        plt.subplot(1, 2, 2)
        plt.plot(history.history['rmse'], label='Training RMSE')
        plt.plot(history.history['val_rmse'], label='Validation RMSE')
        plt.title(f'{model_name} - RMSE')
        plt.xlabel('Epoch')
        plt.ylabel('RMSE')
        plt.legend()
    
    elif 'mae' in history.history:
        plt.subplot(1, 2, 2)
        plt.plot(history.history['mae'], label='Training MAE')
        plt.plot(history.history['val_mae'], label='Validation MAE')
        plt.title(f'{model_name} - MAE')
        plt.xlabel('Epoch')
        plt.ylabel('MAE')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
plot_training_history(single_history, model_name="Single-Cycle Model")
plot_training_history(window_history, model_name="Sliding-Window Model")
