# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed,SimpleRNN,Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_excel("D:\\Projects\\BDA\\aircraft_reliability\\data\\PM_train.xlsx")
df_truth = pd.read_excel("D:\\Projects\\BDA\\aircraft_reliability\\data\\PM_truth.xlsx")

# %%
df_merged = pd.merge(df, df_truth, on='id')
df_merged
# Out:
#        id  cycle  setting1  setting2  setting3      s1      s2       s3  \
# 0       1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70
# 1       1      2    0.0019   -0.0003       100  518.67  642.15  1591.82
# 2       1      3   -0.0043    0.0003       100  518.67  642.35  1587.99
# 3       1      4    0.0007    0.0000       100  518.67  642.35  1582.79
# 4       1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85
# ...    ..    ...       ...       ...       ...     ...     ...      ...
# 20426  99    181   -0.0015   -0.0001       100  518.67  643.72  1600.39
# 20427  99    182   -0.0027   -0.0003       100  518.67  643.52  1605.33
# 20428  99    183   -0.0031   -0.0003       100  518.67  643.96  1606.95
# 20429  99    184   -0.0010   -0.0001       100  518.67  644.10  1600.20
# 20430  99    185   -0.0019   -0.0004       100  518.67  643.93  1598.42
#
#             s4     s5  ...      s13      s14     s15   s16  s17   s18  s19  \
# 0      1400.60  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100
# 1      1403.14  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100
# 2      1404.20  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100
# 3      1401.87  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100
# 4      1406.22  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100
# ...        ...    ...  ...      ...      ...     ...   ...  ...   ...  ...
# 20426  1428.03  14.62  ...  2388.29  8123.55  8.4885  0.03  396  2388  100
# 20427  1430.32  14.62  ...  2388.27  8130.99  8.5124  0.03  393  2388  100
# 20428  1427.90  14.62  ...  2388.31  8126.90  8.5374  0.03  395  2388  100
# 20429  1436.54  14.62  ...  2388.33  8125.66  8.5592  0.03  395  2388  100
# 20430  1421.56  14.62  ...  2388.24  8127.53  8.5425  0.03  397  2388  100
#
#          s20      s21  more
# 0      39.06  23.4190    98
# 1      39.00  23.4236    98
# 2      38.95  23.3442    98
# 3      38.88  23.3739    98
# 4      38.90  23.4044    98
# ...      ...      ...   ...
# 20426  38.50  23.0425    20
# 20427  38.39  22.9674    20
# 20428  38.57  23.1440    20
# 20429  38.45  23.0478    20
# 20430  38.49  23.1931    20
#
# [20431 rows x 27 columns]

# %%
# Step 1: Get the maximum cycle for each engine
max_cycle_per_engine = df.groupby('id')['cycle'].max().reset_index()
max_cycle_per_engine.columns = ['id', 'max_cycle']

# Step 2: Merge the maximum cycle with the df_truth to get the actual failure cycle
df_merged = pd.merge(max_cycle_per_engine, df_truth, on='id')

# Step 3: Calculate the actual failure cycle (when engine will fail)
df_merged['failure_cycle'] = df_merged['max_cycle'] + df_merged['more']

# Step 4: Merge this back with the main DataFrame to compute remaining cycles
df = pd.merge(df, df_merged[['id', 'failure_cycle']], on='id')

# Step 5: Calculate remaining cycles for each row by subtracting the current cycle from the failure cycle
df['remaining_cycles'] = df['failure_cycle'] - df['cycle']
df = df.drop('failure_cycle',axis=1)

# %%
df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0007   -0.0004       100  518.67  641.82  1589.70  1400.60
# 1   1      2    0.0019   -0.0003       100  518.67  642.15  1591.82  1403.14
# 2   1      3   -0.0043    0.0003       100  518.67  642.35  1587.99  1404.20
# 3   1      4    0.0007    0.0000       100  518.67  642.35  1582.79  1401.87
# 4   1      5   -0.0019   -0.0002       100  518.67  642.37  1582.85  1406.22
#
#       s5  ...      s13      s14     s15   s16  s17   s18  s19    s20      s21  \
# 0  14.62  ...  2388.02  8138.62  8.4195  0.03  392  2388  100  39.06  23.4190
# 1  14.62  ...  2388.07  8131.49  8.4318  0.03  392  2388  100  39.00  23.4236
# 2  14.62  ...  2388.03  8133.23  8.4178  0.03  390  2388  100  38.95  23.3442
# 3  14.62  ...  2388.08  8133.83  8.3682  0.03  392  2388  100  38.88  23.3739
# 4  14.62  ...  2388.04  8133.80  8.4294  0.03  393  2388  100  38.90  23.4044
#
#    remaining_cycles
# 0               289
# 1               288
# 2               287
# 3               286
# 4               285
#
# [5 rows x 27 columns]

# %%
# Assuming `df` is the provided DataFrame
# Split engines into train and test ensuring no overlap of engine IDs
engine_ids = df['id'].unique()
train_ids, test_ids = train_test_split(engine_ids, test_size=0.3, random_state=42)
train_ids,val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)
# Create train and test sets
train_df = df[df['id'].isin(train_ids)].reset_index(drop=True)
test_df = df[df['id'].isin(test_ids)].reset_index(drop=True)
val_df = df[df['id'].isin(val_ids)].reset_index(drop=True)

# %%
# def create_sequences(df, sequence_length=50):
#     X_seq, y_seq = [], []
#     for engine_id, group in df.groupby('id'):
#         # Ensure the group is sorted by cycle
#         group = group.sort_values('cycle')
#         # Create sequences
#         for start in range(len(group) - sequence_length):
#             end = start + sequence_length
#             sequence = group.iloc[start:end]
#             X_seq.append(sequence[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
#             y_seq.append(sequence['remaining_cycles'].values[-1])
#     return np.array(X_seq), np.array(y_seq)

# %%
def create_sequences_2(df, window_size=50):
    X_row_seq, y_row_seq = [], []
    X_window_seq, y_window_seq = [], []
    
    for engine_id, group in df.groupby('id'):
        # Ensure the group is sorted by cycle
        group = group.sort_values('cycle')
        
        # Row-wise sequence (each row as a single sequence)
        for _, row in group.iterrows():
            # Append each row as a sequence of length 1 for row-wise model
            X_row_seq.append(row[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
            y_row_seq.append(row['remaining_cycles'])
        
        # Sliding window sequence
        for start in range(len(group) - window_size + 1):
            end = start + window_size
            sequence = group.iloc[start:end]
            X_window_seq.append(sequence[['setting1', 'setting2', 'setting3'] + [f's{i}' for i in range(1, 22)]].values)
            y_window_seq.append(sequence['remaining_cycles'].values[-1])  # Target is the RUL of the last cycle in window
    
    # Convert to numpy arrays
    X_row_seq = np.array(X_row_seq).reshape(-1, 1, len(X_row_seq[0]))  # Shape (num_rows, 1, num_features)
    y_row_seq = np.array(y_row_seq)
    X_window_seq = np.array(X_window_seq)  # Shape (num_windows, window_size, num_features)
    y_window_seq = np.array(y_window_seq)
    
    # Debugging output for shape verification
    print(f"Shape of X_row_seq: {X_row_seq.shape}")  # Should be (num_rows, 1, num_features)
    print(f"Shape of y_row_seq: {y_row_seq.shape}")  # Should be (num_rows,)
    print(f"Shape of X_window_seq: {X_window_seq.shape}")  # Should be (num_windows, window_size, num_features)
    print(f"Shape of y_window_seq: {y_window_seq.shape}")  # Should be (num_windows,)
    
    return X_row_seq, y_row_seq, X_window_seq, y_window_seq

# %%
xtrain_single, ytrain_single, xtrain_window, ytrain_window = create_sequences_2(train_df)
# Out:
# Shape of X_row_seq: (11433, 1, 24)
# Shape of y_row_seq: (11433,)
# Shape of X_window_seq: (8738, 50, 24)
# Shape of y_window_seq: (8738,)

# %%
xtest_single,ytest_single,xtest_window,ytest_window = create_sequences_2(test_df)
# Out:
# Shape of X_row_seq: (6061, 1, 24)
# Shape of y_row_seq: (6061,)
# Shape of X_window_seq: (4591, 50, 24)
# Shape of y_window_seq: (4591,)

# %%
xval_single,yval_single,xval_window,yval_window = create_sequences_2(val_df)
# Out:
# Shape of X_row_seq: (2937, 1, 24)
# Shape of y_row_seq: (2937,)
# Shape of X_window_seq: (2251, 50, 24)
# Shape of y_window_seq: (2251,)

# %%
#train test val of single

num_features = xtrain_single.shape[2]
scaler = StandardScaler()
Xtrain_reshaped = xtrain_single.reshape(-1, num_features)
X_train_scaled = scaler.fit_transform(Xtrain_reshaped)
Xtrain_scaled_single = X_train_scaled.reshape(xtrain_single.shape)

X_test_reshaped = xtest_single.reshape(-1, num_features)
X_test_scaled = scaler.transform(X_test_reshaped)  # Only transform on test data
Xtest_scaled_single = X_test_scaled.reshape(xtest_single.shape)

X_val_reshaped = xval_single.reshape(-1, num_features)
X_val_scaled = scaler.transform(X_val_reshaped)  # Only transform on test data
Xval_scaled_single = X_val_scaled.reshape(xval_single.shape)

# %%
#train test val of window

scaler = StandardScaler()
Xtrain_reshaped = xtrain_window.reshape(-1, num_features)
X_train_scaled = scaler.fit_transform(Xtrain_reshaped)
Xtrain_scaled_window = X_train_scaled.reshape(xtrain_window.shape)

X_test_reshaped = xtest_window.reshape(-1, num_features)
X_test_scaled = scaler.transform(X_test_reshaped)  # Only transform on test data
Xtest_scaled_window = X_test_scaled.reshape(xtest_window.shape)

X_val_reshaped = xval_window.reshape(-1, num_features)
X_val_scaled = scaler.transform(X_val_reshaped)  # Only transform on test data
Xval_scaled_window = X_val_scaled.reshape(xval_window.shape)

# %%
# Count the number of unique engines in train and test sets
num_train_engines = train_df['id'].nunique()
num_test_engines = test_df['id'].nunique()

print(f"Number of engines in training set: {num_train_engines}")
print(f"Number of engines in test set: {num_test_engines}")

# Sum the cycles per engine
train_cycles_per_engine = train_df.groupby('id').size()
test_cycles_per_engine = test_df.groupby('id').size()

print(f"Total cycles in training set: {train_cycles_per_engine.sum()}")
print(f"Total cycles in test set: {test_cycles_per_engine.sum()}")

# Optional: Check average cycles per engine
print(f"Average cycles per engine in training set: {train_cycles_per_engine.mean()}")
print(f"Average cycles per engine in test set: {test_cycles_per_engine.mean()}")
# Out:
# Number of engines in training set: 55
# Number of engines in test set: 30
# Total cycles in training set: 11433
# Total cycles in test set: 6061
# Average cycles per engine in training set: 207.87272727272727
# Average cycles per engine in test set: 202.03333333333333

# %%
single_model = Sequential()
single_model.add(SimpleRNN(100, activation='relu', input_shape=(1, num_features)))
single_model.add(Dense(1))
single_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
# Train the model
single_history = single_model.fit(Xtrain_scaled_single, ytrain_single,
                    validation_data=(Xval_scaled_single, yval_single),
                    epochs=200, batch_size=64,
                    callbacks=tf.keras.callbacks.EarlyStopping(patience=10,monitor='loss'))
# Out:
# Epoch 1/200
# 179/179 [==============================] - 2s 4ms/step - loss: 36847.6758 - val_loss: 37820.6250
# Epoch 2/200
# 179/179 [==============================] - 0s 2ms/step - loss: 24540.2246 - val_loss: 22604.0332
# Epoch 3/200
# 179/179 [==============================] - 0s 2ms/step - loss: 14583.9951 - val_loss: 15935.5088
# Epoch 4/200
# 179/179 [==============================] - 0s 2ms/step - loss: 11945.4463 - val_loss: 13500.5488
# Epoch 5/200
# 179/179 [==============================] - 0s 3ms/step - loss: 10385.1084 - val_loss: 11333.4482
# Epoch 6/200
# 179/179 [==============================] - 0s 2ms/step - loss: 8788.1924 - val_loss: 9423.8750
# Epoch 7/200
# 179/179 [==============================] - 0s 2ms/step - loss: 7306.8936 - val_loss: 7911.4829
# Epoch 8/200
# 179/179 [==============================] - 0s 3ms/step - loss: 6110.5679 - val_loss: 6800.2642
# Epoch 9/200
# 179/179 [==============================] - 0s 2ms/step - loss: 5223.5049 - val_loss: 6115.8867
# Epoch 10/200
# 179/179 [==============================] - 0s 2ms/step - loss: 4624.5405 - val_loss: 5669.5078
# Epoch 11/200
# 179/179 [==============================] - 0s 2ms/step - loss: 4239.0127 - val_loss: 5385.0439
# Epoch 12/200
# 179/179 [==============================] - 0s 2ms/step - loss: 4005.5684 - val_loss: 5183.8193
# Epoch 13/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3868.0281 - val_loss: 5098.8164
# Epoch 14/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3786.6863 - val_loss: 5076.8877
# Epoch 15/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3740.3835 - val_loss: 5063.9546
# Epoch 16/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3709.0623 - val_loss: 4983.8481
# Epoch 17/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3687.8171 - val_loss: 5014.3638
# Epoch 18/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3673.2256 - val_loss: 5093.3096
# Epoch 19/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3660.8638 - val_loss: 5085.9790
# Epoch 20/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3654.4854 - val_loss: 5036.2954
# Epoch 21/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3647.0386 - val_loss: 4995.9351
# Epoch 22/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3641.2517 - val_loss: 5010.5879
# Epoch 23/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3635.5486 - val_loss: 5036.6406
# Epoch 24/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3633.0334 - val_loss: 5093.8657
# Epoch 25/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3628.7805 - val_loss: 5125.9185
# Epoch 26/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3626.0378 - val_loss: 5083.8379
# Epoch 27/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3625.2627 - val_loss: 5041.2617
# Epoch 28/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3620.4756 - val_loss: 5023.2041
# Epoch 29/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3620.6587 - val_loss: 5048.9888
# Epoch 30/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3617.4463 - val_loss: 5059.7305
# Epoch 31/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3614.6089 - val_loss: 5148.1157
# Epoch 32/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3614.3928 - val_loss: 5030.3354
# Epoch 33/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3611.7488 - val_loss: 4975.7305
# Epoch 34/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3610.2119 - val_loss: 5142.2974
# Epoch 35/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3612.1089 - val_loss: 5085.5234
# Epoch 36/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3608.7600 - val_loss: 5106.9014
# Epoch 37/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3607.2800 - val_loss: 5154.4033
# Epoch 38/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3607.0295 - val_loss: 5085.0605
# Epoch 39/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3605.5933 - val_loss: 5065.5464
# Epoch 40/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3602.9036 - val_loss: 5152.6768
# Epoch 41/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3605.0779 - val_loss: 5081.9873
# Epoch 42/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3602.2571 - val_loss: 5157.7144
# Epoch 43/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3602.5425 - val_loss: 5080.8154
# Epoch 44/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3598.8882 - val_loss: 5106.8584
# Epoch 45/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3603.0386 - val_loss: 5080.7725
# Epoch 46/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3598.0854 - val_loss: 5098.7388
# Epoch 47/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3599.5151 - val_loss: 5108.7905
# Epoch 48/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3596.1157 - val_loss: 5101.4722
# Epoch 49/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3597.9131 - val_loss: 5142.2729
# Epoch 50/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3595.0386 - val_loss: 5141.1357
# Epoch 51/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3594.9756 - val_loss: 5127.7754
# Epoch 52/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3592.5630 - val_loss: 5125.1445
# Epoch 53/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3594.8171 - val_loss: 5143.7188
# Epoch 54/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3590.6477 - val_loss: 5189.7861
# Epoch 55/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3589.1167 - val_loss: 5107.6987
# Epoch 56/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3587.2092 - val_loss: 5094.6440
# Epoch 57/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3588.1287 - val_loss: 5109.0635
# Epoch 58/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3587.8220 - val_loss: 5150.4360
# Epoch 59/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3586.8044 - val_loss: 5066.6064
# Epoch 60/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3585.4253 - val_loss: 5056.5244
# Epoch 61/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3583.9683 - val_loss: 5081.6382
# Epoch 62/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3583.3389 - val_loss: 5169.5933
# Epoch 63/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3582.9297 - val_loss: 5088.4722
# Epoch 64/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3582.9360 - val_loss: 5163.3271
# Epoch 65/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3580.0405 - val_loss: 5090.1885
# Epoch 66/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3578.6538 - val_loss: 5126.8057
# Epoch 67/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3574.8452 - val_loss: 5033.3848
# Epoch 68/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3580.6445 - val_loss: 5035.2085
# Epoch 69/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3575.0747 - val_loss: 5092.4673
# Epoch 70/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3576.0676 - val_loss: 5176.2568
# Epoch 71/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3575.1348 - val_loss: 5072.1646
# Epoch 72/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3575.1914 - val_loss: 5034.8965
# Epoch 73/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3574.2231 - val_loss: 5083.3604
# Epoch 74/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3577.5244 - val_loss: 5111.8550
# Epoch 75/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3572.6108 - val_loss: 5104.8931
# Epoch 76/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3570.8665 - val_loss: 5160.2603
# Epoch 77/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3569.7053 - val_loss: 5196.6064
# Epoch 78/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3570.0967 - val_loss: 5090.4575
# Epoch 79/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3567.3894 - val_loss: 5074.8125
# Epoch 80/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3568.2012 - val_loss: 5051.4404
# Epoch 81/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3566.8186 - val_loss: 5099.9927
# Epoch 82/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3566.9231 - val_loss: 5147.2354
# Epoch 83/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3566.1985 - val_loss: 5107.3965
# Epoch 84/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3565.3591 - val_loss: 5135.8970
# Epoch 85/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3563.4060 - val_loss: 5139.6455
# Epoch 86/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3561.7805 - val_loss: 5220.5205
# Epoch 87/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3563.5435 - val_loss: 5041.7153
# Epoch 88/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3562.2095 - val_loss: 5064.5967
# Epoch 89/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3564.8945 - val_loss: 5089.5181
# Epoch 90/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3560.3586 - val_loss: 5100.5249
# Epoch 91/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3560.3921 - val_loss: 5169.2241
# Epoch 92/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3557.6108 - val_loss: 5125.4136
# Epoch 93/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3557.8438 - val_loss: 5167.9009
# Epoch 94/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3559.2666 - val_loss: 5085.0376
# Epoch 95/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3556.5542 - val_loss: 5092.6572
# Epoch 96/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3556.2490 - val_loss: 5133.0532
# Epoch 97/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3554.8784 - val_loss: 5166.7383
# Epoch 98/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3555.3264 - val_loss: 5102.8965
# Epoch 99/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3554.1787 - val_loss: 5089.2910
# Epoch 100/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3553.0696 - val_loss: 5041.4326
# Epoch 101/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3554.1089 - val_loss: 5057.5430
# Epoch 102/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3551.6777 - val_loss: 5115.5215
# Epoch 103/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3548.4175 - val_loss: 5025.9307
# Epoch 104/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3549.2727 - val_loss: 5130.7710
# Epoch 105/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3553.8865 - val_loss: 5056.2085
# Epoch 106/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3547.7173 - val_loss: 5057.4575
# Epoch 107/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3549.0867 - val_loss: 5053.8994
# Epoch 108/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3549.1199 - val_loss: 5044.3164
# Epoch 109/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3545.7078 - val_loss: 5074.3931
# Epoch 110/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3547.9348 - val_loss: 5084.3965
# Epoch 111/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3543.5281 - val_loss: 5100.8398
# Epoch 112/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3543.8079 - val_loss: 5023.2075
# Epoch 113/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3543.6023 - val_loss: 4986.1333
# Epoch 114/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3544.2327 - val_loss: 5111.1650
# Epoch 115/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3543.4172 - val_loss: 5029.5356
# Epoch 116/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3543.8135 - val_loss: 5122.0513
# Epoch 117/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3543.6284 - val_loss: 5142.4531
# Epoch 118/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3544.8193 - val_loss: 5126.6396
# Epoch 119/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3540.3552 - val_loss: 5148.2119
# Epoch 120/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3540.9419 - val_loss: 5095.0962
# Epoch 121/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3540.2156 - val_loss: 5137.9067
# Epoch 122/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3540.0256 - val_loss: 5079.6440
# Epoch 123/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3538.3254 - val_loss: 5115.7998
# Epoch 124/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3539.6428 - val_loss: 5053.0737
# Epoch 125/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3538.6340 - val_loss: 5019.6201
# Epoch 126/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3538.7778 - val_loss: 5156.1138
# Epoch 127/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3538.1072 - val_loss: 5145.4863
# Epoch 128/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3534.6548 - val_loss: 5051.1016
# Epoch 129/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3537.7605 - val_loss: 5065.2422
# Epoch 130/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3533.7429 - val_loss: 5049.8691
# Epoch 131/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3533.2043 - val_loss: 5046.5376
# Epoch 132/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3533.4075 - val_loss: 5123.0947
# Epoch 133/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3531.9817 - val_loss: 5008.4526
# Epoch 134/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3531.6050 - val_loss: 5122.9878
# Epoch 135/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3530.8706 - val_loss: 5106.7300
# Epoch 136/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3531.7085 - val_loss: 5092.8975
# Epoch 137/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3532.4292 - val_loss: 5098.7402
# Epoch 138/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3529.8750 - val_loss: 5129.6904
# Epoch 139/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3529.2295 - val_loss: 5083.5376
# Epoch 140/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3528.5420 - val_loss: 5046.6914
# Epoch 141/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3530.2725 - val_loss: 5061.1567
# Epoch 142/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3529.9763 - val_loss: 5143.9937
# Epoch 143/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3526.5239 - val_loss: 5043.6777
# Epoch 144/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3526.8828 - val_loss: 5068.7710
# Epoch 145/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3527.3538 - val_loss: 5106.9238
# Epoch 146/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3525.2141 - val_loss: 5092.3003
# Epoch 147/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3526.5298 - val_loss: 5147.5508
# Epoch 148/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3524.1533 - val_loss: 5014.7622
# Epoch 149/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3523.2356 - val_loss: 5122.2866
# Epoch 150/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3522.3105 - val_loss: 5031.4272
# Epoch 151/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3524.7771 - val_loss: 5108.5127
# Epoch 152/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3523.1880 - val_loss: 5100.9160
# Epoch 153/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3522.4058 - val_loss: 5142.4092
# Epoch 154/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3521.9751 - val_loss: 5167.0894
# Epoch 155/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3520.7102 - val_loss: 5080.3184
# Epoch 156/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3520.9436 - val_loss: 5070.2041
# Epoch 157/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3522.4434 - val_loss: 5088.5122
# Epoch 158/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3519.6213 - val_loss: 5124.8540
# Epoch 159/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3519.7690 - val_loss: 5103.5059
# Epoch 160/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3518.5068 - val_loss: 5119.3540
# Epoch 161/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3520.4792 - val_loss: 5132.0029
# Epoch 162/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3517.3047 - val_loss: 5182.6382
# Epoch 163/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3519.4690 - val_loss: 5131.8579
# Epoch 164/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3517.9124 - val_loss: 5077.7305
# Epoch 165/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3517.1707 - val_loss: 5077.2778
# Epoch 166/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3515.9280 - val_loss: 5104.2617
# Epoch 167/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3515.2898 - val_loss: 5011.0522
# Epoch 168/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3516.0386 - val_loss: 5151.4849
# Epoch 169/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3515.8359 - val_loss: 5103.7827
# Epoch 170/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3514.1311 - val_loss: 5052.3359
# Epoch 171/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3513.7288 - val_loss: 5067.0308
# Epoch 172/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3515.4382 - val_loss: 5051.2866
# Epoch 173/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3511.8311 - val_loss: 5168.0947
# Epoch 174/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3513.1130 - val_loss: 5122.6934
# Epoch 175/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3513.3389 - val_loss: 5101.1436
# Epoch 176/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3510.4834 - val_loss: 5138.0986
# Epoch 177/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3510.4624 - val_loss: 4993.9409
# Epoch 178/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3512.2239 - val_loss: 5132.5210
# Epoch 179/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3511.3220 - val_loss: 5061.6060
# Epoch 180/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3507.9216 - val_loss: 5006.8159
# Epoch 181/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3510.2549 - val_loss: 5043.1157
# Epoch 182/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3508.1826 - val_loss: 5100.6143
# Epoch 183/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3509.7122 - val_loss: 5082.1118
# Epoch 184/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3509.7349 - val_loss: 5087.1821
# Epoch 185/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3508.6851 - val_loss: 5095.1187
# Epoch 186/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3506.8970 - val_loss: 5016.1440
# Epoch 187/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3507.5056 - val_loss: 5092.3149
# Epoch 188/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3506.1821 - val_loss: 5021.3696
# Epoch 189/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3503.5757 - val_loss: 5112.0068
# Epoch 190/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3507.1147 - val_loss: 5094.7144
# Epoch 191/200
# 179/179 [==============================] - 1s 3ms/step - loss: 3504.9519 - val_loss: 5096.1968
# Epoch 192/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3504.1575 - val_loss: 5171.6001
# Epoch 193/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3504.0298 - val_loss: 5105.4209
# Epoch 194/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3504.3975 - val_loss: 5034.5088
# Epoch 195/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3504.0171 - val_loss: 5064.7417
# Epoch 196/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3506.1533 - val_loss: 5097.0454
# Epoch 197/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3503.4072 - val_loss: 5031.4922
# Epoch 198/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3503.9072 - val_loss: 5093.4146
# Epoch 199/200
# 179/179 [==============================] - 0s 2ms/step - loss: 3502.6025 - val_loss: 5050.9102
# Epoch 200/200
# 179/179 [==============================] - 0s 3ms/step - loss: 3502.5483 - val_loss: 5102.4653

# %%
window_len = 50

window_model = Sequential()
window_model.add(SimpleRNN(150, activation='relu', input_shape=(window_len, num_features)))
window_model.add(Dense(1))
window_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# %%
# Train the model
window_history = window_model.fit(Xtrain_scaled_window, ytrain_window,
                                  validation_data=(Xval_scaled_window, yval_window),
                    epochs=100, batch_size=64,
                    callbacks=tf.keras.callbacks.EarlyStopping(patience=10,monitor='val_loss'))
# Out:
# Epoch 1/100
# 137/137 [==============================] - 3s 18ms/step - loss: 18230.7852 - val_loss: 5511.2007
# Epoch 2/100
# 137/137 [==============================] - 2s 17ms/step - loss: 3810.9233 - val_loss: 6078.8633
# Epoch 3/100
# 137/137 [==============================] - 2s 17ms/step - loss: 3513.1213 - val_loss: 5454.0757
# Epoch 4/100
# 137/137 [==============================] - 2s 17ms/step - loss: 2921.8596 - val_loss: 4708.7964
# Epoch 5/100
# 137/137 [==============================] - 2s 16ms/step - loss: 2476.0100 - val_loss: 5291.8823
# Epoch 6/100
# 137/137 [==============================] - 2s 17ms/step - loss: 2414.9441 - val_loss: 7193.7461
# Epoch 7/100
# 137/137 [==============================] - 2s 16ms/step - loss: 1980.2119 - val_loss: 6262.8457
# Epoch 8/100
# 137/137 [==============================] - 2s 17ms/step - loss: 1658.7328 - val_loss: 5600.0024
# Epoch 9/100
# 137/137 [==============================] - 2s 17ms/step - loss: 1165.8049 - val_loss: 5620.0620
# Epoch 10/100
# 137/137 [==============================] - 2s 17ms/step - loss: 785.2851 - val_loss: 5812.6738
# Epoch 11/100
# 137/137 [==============================] - 2s 17ms/step - loss: 2946.2798 - val_loss: 5127.8667
# Epoch 12/100
# 137/137 [==============================] - 2s 17ms/step - loss: 640.6769 - val_loss: 5368.8203
# Epoch 13/100
# 137/137 [==============================] - 2s 17ms/step - loss: 533.5198 - val_loss: 5603.9219
# Epoch 14/100
# 137/137 [==============================] - 2s 17ms/step - loss: 503.8449 - val_loss: 5575.3975

# %%
# Plotting function
def plot_loss(history, title,lim=(None,None)):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(title)
    plt.legend()
    plt.ylim(lim)
    plt.grid(True)
    plt.show()

# Plot for individual row-wise model
plot_loss(single_history, 'Individual Row-wise Model Loss',(3500,5400))

# %%
plot_loss(window_history,'Window Model Loss',)

# %%
# Adjusted evaluation function
def evaluate_model(model, X_test, y_test,type):
    predictions = model.predict(X_test)
    if predictions.shape[0] != y_test.shape[0]:
        # Trimming to the minimum size for consistency
        min_len = min(predictions.shape[0], y_test.shape[0])
        predictions = predictions[:min_len]
        y_test = y_test[:min_len]
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    mae = mean_absolute_error(y_test, predictions)
    print(f"{type} Model Evaluation - RMSE: {rmse:.2f}, MAE: {mae:.2f}")
    return predictions, rmse, mae

# %%
def get_combined_predictions(pred_single, pred_window):
    """
    Combines predictions from single-model and window-model predictions.

    Args:
        pred_single (np.array): Predictions from the single-model.
        pred_window (np.array): Predictions from the window-model.

    Returns:
        combined_predictions (np.array): Averaged predictions.
    """
    # Ensure the predictions are reshaped to (n_samples, 1) for averaging
    pred_single = np.array(pred_single).reshape(-1, 1)
    pred_window = np.array(pred_window).reshape(-1, 1)
    
    # Average the predictions
    combined_predictions = (pred_single + pred_window) / 2
    return combined_predictions

# %%
# Now update the combined evaluation to use trimmed predictions
def evaluate_combined_model(pred_single, pred_window, y_test):
    # Trim both predictions and y_test to the minimum shared length
    min_len = min(len(pred_single), len(pred_window), len(y_test))
    pred_single, pred_window, y_test = pred_single[:min_len], pred_window[:min_len], y_test[:min_len]

    # Get combined predictions
    combined_predictions = (pred_single + pred_window) / 2
    rmse = np.sqrt(mean_squared_error(y_test, combined_predictions))
    mae = mean_absolute_error(y_test, combined_predictions)
    print(f"Combined Model Evaluation - RMSE: {rmse:.2f}, MAE: {mae:.2f}")
    return combined_predictions, rmse, mae

# %%
# Get predictions and evaluate each model individually
pred_single, rmse_single, mae_single = evaluate_model(single_model, Xtest_scaled_single, ytest_single,'single')
pred_window, rmse_window, mae_window = evaluate_model(window_model, Xtest_scaled_window, ytest_window,'window')

# Evaluate combined predictions
combined_predictions, rmse_combined, mae_combined = evaluate_combined_model(pred_single, pred_window, ytest_single)
# Out:
# 190/190 [==============================] - 0s 1ms/step
# single Model Evaluation - RMSE: 59.21, MAE: 46.49
# 144/144 [==============================] - 1s 5ms/step
# window Model Evaluation - RMSE: 66.65, MAE: 52.52
# Combined Model Evaluation - RMSE: 70.98, MAE: 54.85
